# %%
import pandas as pd
import numpy as np
import multiprocessing
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import gc
from time import time
import datetime
from tqdm import tqdm_notebook
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, TimeSeriesSplit
from sklearn.metrics import roc_auc_score
warnings.simplefilter('ignore')
sns.set()
# %matplotlib inline

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train_transaction = pd.read_csv('G:\Data Sets\IEEE\Train_transaction.csv', index_col='TransactionID')
test_transaction = pd.read_csv('G:\Data Sets\IEEE\Test_transaction.csv', index_col='TransactionID')
train_identity = pd.read_csv('G:\Data Sets\IEEE\Train_identity.csv', index_col='TransactionID')
test_identity = pd.read_csv('G:\Data Sets\IEEE\Test_identity.csv', index_col='TransactionID')
sample_submission = pd.read_csv('G:\Data Sets\IEEE\sample_submission.csv', index_col='TransactionID')

train = train_transaction.merge(train_identity, how='left', left_index=True, right_index=True)
del train_transaction, train_identity
gc.collect()
test = test_transaction.merge(test_identity, how='left', left_index=True, right_index=True)
del test_transaction, test_identity
gc.collect

train=reduce_mem_usage(train)
test=reduce_mem_usage(test)
print('training set shape:', train.shape)
print('test set shape:', test.shape)
# Out:
# Mem. usage decreased to 668.22 Mb (66.2% reduction)
# Mem. usage decreased to 583.43 Mb (65.6% reduction)
# training set shape: (590540, 433)
# test set shape: (506691, 432)

# %%
useful_features = ['TransactionAmt', 'ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'addr1', 'addr2', 'dist1',
                   'P_emaildomain', 'R_emaildomain', 'C1', 'C2', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13',
                   'C14', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D8', 'D9', 'D10', 'D11', 'D12', 'D13', 'D14', 'D15', 'M2', 'M3',
                   'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V17',
                   'V19', 'V20', 'V29', 'V30', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V40', 'V44', 'V45', 'V46', 'V47', 'V48',
                   'V49', 'V51', 'V52', 'V53', 'V54', 'V56', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63', 'V64', 'V69', 'V70', 'V71',
                   'V72', 'V73', 'V74', 'V75', 'V76', 'V78', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V87', 'V90', 'V91', 'V92',
                   'V93', 'V94', 'V95', 'V96', 'V97', 'V99', 'V100', 'V126', 'V127', 'V128', 'V130', 'V131', 'V138', 'V139', 'V140',
                   'V143', 'V145', 'V146', 'V147', 'V149', 'V150', 'V151', 'V152', 'V154', 'V156', 'V158', 'V159', 'V160', 'V161',
                   'V162', 'V163', 'V164', 'V165', 'V166', 'V167', 'V169', 'V170', 'V171', 'V172', 'V173', 'V175', 'V176', 'V177',
                   'V178', 'V180', 'V182', 'V184', 'V187', 'V188', 'V189', 'V195', 'V197', 'V200', 'V201', 'V202', 'V203', 'V204',
                   'V205', 'V206', 'V207', 'V208', 'V209', 'V210', 'V212', 'V213', 'V214', 'V215', 'V216', 'V217', 'V219', 'V220',
                   'V221', 'V222', 'V223', 'V224', 'V225', 'V226', 'V227', 'V228', 'V229', 'V231', 'V233', 'V234', 'V238', 'V239',
                   'V242', 'V243', 'V244', 'V245', 'V246', 'V247', 'V249', 'V251', 'V253', 'V256', 'V257', 'V258', 'V259', 'V261',
                   'V262', 'V263', 'V264', 'V265', 'V266', 'V267', 'V268', 'V270', 'V271', 'V272', 'V273', 'V274', 'V275', 'V276',
                   'V277', 'V278', 'V279', 'V280', 'V282', 'V283', 'V285', 'V287', 'V288', 'V289', 'V291', 'V292', 'V294', 'V303',
                   'V304', 'V306', 'V307', 'V308', 'V310', 'V312', 'V313', 'V314', 'V315', 'V317', 'V322', 'V323', 'V324', 'V326',
                   'V329', 'V331', 'V332', 'V333', 'V335', 'V336', 'V338', 'id_01', 'id_02', 'id_03', 'id_05', 'id_06', 'id_09',
                   'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_17', 'id_19', 'id_20', 'id_30', 'id_31', 'id_32', 'id_33',
                   'id_36', 'id_37', 'id_38', 'DeviceType', 'DeviceInfo']

# %%
train.reset_index()
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400       68.500000         W
# 1             2987001        0          86401       29.000000         W
# 2             2987002        0          86469       59.000000         W
# 3             2987003        0          86499       50.000000         W
# 4             2987004        0          86506       50.000000         H
# 5             2987005        0          86510       49.000000         W
# 6             2987006        0          86522      159.000000         W
# 7             2987007        0          86529      422.500000         W
# 8             2987008        0          86535       15.000000         H
# 9             2987009        0          86536      117.000000         W
# 10            2987010        0          86549       75.875000         C
# 11            2987011        0          86555       16.500000         C
# 12            2987012        0          86564       50.000000         W
# 13            2987013        0          86585       40.000000         W
# 14            2987014        0          86596       10.500000         W
# 15            2987015        0          86618       57.937500         W
# 16            2987016        0          86620       30.000000         H
# 17            2987017        0          86668      100.000000         H
# 18            2987018        0          86725       47.937500         W
# 19            2987019        0          86730      186.000000         W
# 20            2987020        0          86761       39.000000         W
# 21            2987021        0          86769      160.000000         W
# 22            2987022        0          86786       50.000000         H
# 23            2987023        0          86808      107.937500         W
# 24            2987024        0          86821       73.937500         W
# 25            2987025        0          86944      107.937500         W
# 26            2987026        0          86945      184.000000         W
# 27            2987027        0          86972       47.937500         W
# 28            2987028        0          86973       20.000000         W
# 29            2987029        0          86979       37.000000         W
# ...               ...      ...            ...             ...       ...
# 590510        3577510        0       15810518       24.500000         W
# 590511        3577511        0       15810549      131.000000         W
# 590512        3577512        0       15810563      764.000000         W
# 590513        3577513        0       15810575      107.937500         W
# 590514        3577514        0       15810578      160.000000         W
# 590515        3577515        0       15810589      108.500000         W
# 590516        3577516        0       15810592      761.000000         W
# 590517        3577517        0       15810626      764.000000         W
# 590518        3577518        0       15810760       49.000000         W
# 590519        3577519        0       15810774     1660.000000         W
# 590520        3577520        0       15810785       93.000000         W
# 590521        3577521        0       15810802       48.875000         C
# 590522        3577522        0       15810823       54.500000         W
# 590523        3577523        0       15810833       58.937500         W
# 590524        3577524        0       15810836       75.000000         W
# 590525        3577525        0       15810866       57.937500         W
# 590526        3577526        1       15810876      250.000000         R
# 590527        3577527        0       15810883      190.000000         W
# 590528        3577528        0       15810907      280.000000         W
# 590529        3577529        0       15810912       73.812500         C
# 590530        3577530        0       15810926      400.750000         W
# 590531        3577531        0       15810935      400.000000         R
# 590532        3577532        0       15811007      205.000000         W
# 590533        3577533        0       15811029      107.937500         W
# 590534        3577534        0       15811030       67.500000         C
# 590535        3577535        0       15811047       49.000000         W
# 590536        3577536        0       15811049       39.500000         W
# 590537        3577537        0       15811079       30.953125         W
# 590538        3577538        0       15811088      117.000000         W
# 590539        3577539        0       15811131      280.000000         W
#
#         card1  card2  card3       card4  card5  ...                    id_31  \
# 0       13926    NaN  150.0    discover  142.0  ...                      NaN
# 1        2755  404.0  150.0  mastercard  102.0  ...                      NaN
# 2        4663  490.0  150.0        visa  166.0  ...                      NaN
# 3       18132  567.0  150.0  mastercard  117.0  ...                      NaN
# 4        4497  514.0  150.0  mastercard  102.0  ...      samsung browser 6.2
# 5        5937  555.0  150.0        visa  226.0  ...                      NaN
# 6       12308  360.0  150.0        visa  166.0  ...                      NaN
# 7       12695  490.0  150.0        visa  226.0  ...                      NaN
# 8        2803  100.0  150.0        visa  226.0  ...       mobile safari 11.0
# 9       17399  111.0  150.0  mastercard  224.0  ...                      NaN
# 10      16496  352.0  117.0  mastercard  134.0  ...              chrome 62.0
# 11       4461  375.0  185.0  mastercard  224.0  ...              chrome 62.0
# 12       3786  418.0  150.0        visa  226.0  ...                      NaN
# 13      12866  303.0  150.0        visa  226.0  ...                      NaN
# 14      11839  490.0  150.0        visa  226.0  ...                      NaN
# 15       7055  555.0  150.0        visa  226.0  ...                      NaN
# 16       1790  555.0  150.0        visa  226.0  ...              chrome 62.0
# 17      11492  111.0  150.0  mastercard  219.0  ...              chrome 62.0
# 18       4663  490.0  150.0        visa  166.0  ...                      NaN
# 19       7005  111.0  150.0        visa  226.0  ...                      NaN
# 20       7875  314.0  150.0  mastercard  224.0  ...                      NaN
# 21      11401  543.0  150.0  mastercard  117.0  ...                      NaN
# 22       1724  583.0  150.0        visa  226.0  ...                      NaN
# 23       2392  360.0  150.0  mastercard  166.0  ...                      NaN
# 24      10112  360.0  150.0        visa  166.0  ...                      NaN
# 25      15385  111.0  150.0  mastercard  224.0  ...                      NaN
# 26      17868  148.0  150.0        visa  226.0  ...                      NaN
# 27      11307  321.0  150.0        visa  226.0  ...                      NaN
# 28       8431  269.0  150.0  mastercard  224.0  ...                      NaN
# 29      12932  361.0  150.0        visa  226.0  ...                      NaN
# ...       ...    ...    ...         ...    ...  ...                      ...
# 590510   9500  321.0  150.0        visa  226.0  ...                      NaN
# 590511  12059  555.0  150.0        visa  226.0  ...                      NaN
# 590512  16873  343.0  150.0        visa  226.0  ...                      NaN
# 590513   2198  555.0  150.0        visa  166.0  ...                      NaN
# 590514   2487  555.0  150.0        visa  226.0  ...                      NaN
# 590515   4219  321.0  150.0        visa  226.0  ...                      NaN
# 590516  17188  321.0  150.0        visa  226.0  ...                      NaN
# 590517  16873  343.0  150.0        visa  226.0  ...                      NaN
# 590518  11204  298.0  150.0        visa  226.0  ...                      NaN
# 590519  18018  452.0  150.0  mastercard  117.0  ...                      NaN
# 590520  17150  292.0  150.0        visa  226.0  ...                      NaN
# 590521  12019  305.0  106.0  mastercard  224.0  ...  chrome 66.0 for android
# 590522   3166  559.0  150.0        visa  166.0  ...                      NaN
# 590523  13076  456.0  150.0  mastercard  117.0  ...                      NaN
# 590524   7826  481.0  150.0  mastercard  224.0  ...                      NaN
# 590525  11942  570.0  150.0        visa  226.0  ...                      NaN
# 590526   1214  174.0  150.0        visa  226.0  ...  chrome 55.0 for android
# 590527   6453  555.0  150.0        visa  226.0  ...                      NaN
# 590528  15066  170.0  150.0  mastercard  102.0  ...                      NaN
# 590529   5096  555.0  185.0  mastercard  137.0  ...  chrome 65.0 for android
# 590530  15066  170.0  150.0  mastercard  102.0  ...                      NaN
# 590531   6019  583.0  150.0        visa  226.0  ...              chrome 66.0
# 590532  12037  595.0  150.0  mastercard  224.0  ...                      NaN
# 590533  13071  321.0  150.0        visa  226.0  ...                      NaN
# 590534   5812  408.0  185.0  mastercard  224.0  ...  chrome 66.0 for android
# 590535   6550    NaN  150.0        visa  226.0  ...                      NaN
# 590536  10444  225.0  150.0  mastercard  224.0  ...                      NaN
# 590537  12037  595.0  150.0  mastercard  224.0  ...                      NaN
# 590538   7826  481.0  150.0  mastercard  224.0  ...                      NaN
# 590539  15066  170.0  150.0  mastercard  102.0  ...                      NaN
#
#         id_32      id_33           id_34  id_35 id_36 id_37  id_38  \
# 0         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 1         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 2         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 3         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 4        32.0  2220x1080  match_status:2      T     F     T      T
# 5         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 6         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 7         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 8        32.0   1334x750  match_status:1      T     F     F      T
# 9         NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 10        NaN        NaN             NaN      F     F     T      T
# 11        NaN        NaN             NaN      F     F     T      T
# 12        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 13        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 14        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 15        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 16       24.0   1280x800  match_status:2      T     F     T      T
# 17       24.0   1366x768  match_status:2      T     F     T      T
# 18        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 19        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 20        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 21        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 22        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 23        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 24        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 25        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 26        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 27        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 28        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 29        NaN        NaN             NaN    NaN   NaN   NaN    NaN
# ...       ...        ...             ...    ...   ...   ...    ...
# 590510    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590511    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590512    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590513    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590514    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590515    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590516    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590517    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590518    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590519    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590520    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590521    NaN        NaN             NaN      F     F     T      F
# 590522    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590523    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590524    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590525    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590526   32.0    855x480  match_status:2      T     F     T      F
# 590527    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590528    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590529    NaN        NaN             NaN      F     F     T      F
# 590530    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590531   24.0  2560x1600  match_status:2      T     F     T      F
# 590532    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590533    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590534    NaN        NaN             NaN      F     F     T      F
# 590535    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590536    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590537    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590538    NaN        NaN             NaN    NaN   NaN   NaN    NaN
# 590539    NaN        NaN             NaN    NaN   NaN   NaN    NaN
#
#         DeviceType                          DeviceInfo
# 0              NaN                                 NaN
# 1              NaN                                 NaN
# 2              NaN                                 NaN
# 3              NaN                                 NaN
# 4           mobile       SAMSUNG SM-G892A Build/NRD90M
# 5              NaN                                 NaN
# 6              NaN                                 NaN
# 7              NaN                                 NaN
# 8           mobile                          iOS Device
# 9              NaN                                 NaN
# 10         desktop                             Windows
# 11         desktop                                 NaN
# 12             NaN                                 NaN
# 13             NaN                                 NaN
# 14             NaN                                 NaN
# 15             NaN                                 NaN
# 16         desktop                               MacOS
# 17         desktop                             Windows
# 18             NaN                                 NaN
# 19             NaN                                 NaN
# 20             NaN                                 NaN
# 21             NaN                                 NaN
# 22             NaN                                 NaN
# 23             NaN                                 NaN
# 24             NaN                                 NaN
# 25             NaN                                 NaN
# 26             NaN                                 NaN
# 27             NaN                                 NaN
# 28             NaN                                 NaN
# 29             NaN                                 NaN
# ...            ...                                 ...
# 590510         NaN                                 NaN
# 590511         NaN                                 NaN
# 590512         NaN                                 NaN
# 590513         NaN                                 NaN
# 590514         NaN                                 NaN
# 590515         NaN                                 NaN
# 590516         NaN                                 NaN
# 590517         NaN                                 NaN
# 590518         NaN                                 NaN
# 590519         NaN                                 NaN
# 590520         NaN                                 NaN
# 590521      mobile             F3111 Build/33.3.A.1.97
# 590522         NaN                                 NaN
# 590523         NaN                                 NaN
# 590524         NaN                                 NaN
# 590525         NaN                                 NaN
# 590526      mobile                 A574BL Build/NMF26F
# 590527         NaN                                 NaN
# 590528         NaN                                 NaN
# 590529      mobile  Moto E (4) Plus Build/NMA26.42-152
# 590530         NaN                                 NaN
# 590531     desktop                               MacOS
# 590532         NaN                                 NaN
# 590533         NaN                                 NaN
# 590534      mobile         RNE-L03 Build/HUAWEIRNE-L03
# 590535         NaN                                 NaN
# 590536         NaN                                 NaN
# 590537         NaN                                 NaN
# 590538         NaN                                 NaN
# 590539         NaN                                 NaN
#
# [590540 rows x 434 columns]

# %%
test.reset_index()
# Out:
#         TransactionID  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# 0             3663549       18403224       31.953125         W  10409  111.0
# 1             3663550       18403263       49.000000         W   4272  111.0
# 2             3663551       18403310      171.000000         W   4476  574.0
# 3             3663552       18403310      285.000000         W  10989  360.0
# 4             3663553       18403317       67.937500         W  18018  452.0
# 5             3663554       18403323       57.937500         W  12839  321.0
# 6             3663555       18403350       87.000000         W  16560  476.0
# 7             3663556       18403387      390.000000         W  15066  170.0
# 8             3663557       18403405      103.937500         W   2803  100.0
# 9             3663558       18403416      117.000000         W  12544  321.0
# 10            3663559       18403474      262.000000         W  16982  127.0
# 11            3663560       18403504      107.937500         W   9500  321.0
# 12            3663561       18403508      335.000000         W  18366  111.0
# 13            3663562       18403543      107.937500         W   6900  225.0
# 14            3663563       18403553      117.000000         W  12686  215.0
# 15            3663564       18403582       57.937500         W   7826  481.0
# 16            3663565       18403598       57.937500         W   8489  230.0
# 17            3663566       18403632       29.000000         W  12544  321.0
# 18            3663567       18403632       49.000000         W  16560  476.0
# 19            3663568       18403678       77.000000         W  12839  321.0
# 20            3663569       18403686      445.000000         W   7919  194.0
# 21            3663570       18403735      210.000000         W  15066  170.0
# 22            3663571       18403755      554.000000         W  16338  555.0
# 23            3663572       18403788      117.000000         W   6530  206.0
# 24            3663573       18403829      131.000000         W  10752  555.0
# 25            3663574       18403844       77.000000         W  17188  321.0
# 26            3663575       18403848      210.000000         W  15066  170.0
# 27            3663576       18403854      141.000000         W  11839  490.0
# 28            3663577       18403857      117.000000         W   6530  206.0
# 29            3663578       18403863       34.000000         W  14991  555.0
# ...               ...            ...             ...       ...    ...    ...
# 506661        4170210       34213723       49.000000         W  12386  555.0
# 506662        4170211       34213751      280.000000         W   2440  111.0
# 506663        4170212       34213763      107.937500         W  12866  303.0
# 506664        4170213       34213767      186.000000         W   5137  555.0
# 506665        4170214       34213780       20.906250         C   4461  375.0
# 506666        4170215       34213798       73.000000         W   4702  111.0
# 506667        4170216       34213812       77.000000         W   7690  122.0
# 506668        4170217       34213826       67.937500         W  17399  111.0
# 506669        4170218       34213834       77.000000         W   1675  174.0
# 506670        4170219       34213938      142.000000         C   4461  375.0
# 506671        4170220       34213992      107.937500         W  10023  111.0
# 506672        4170221       34214060       59.000000         W   1675  174.0
# 506673        4170222       34214073       19.500000         W   5561  555.0
# 506674        4170223       34214101       31.359375         C  16136  204.0
# 506675        4170224       34214125        7.007812         C   2650  142.0
# 506676        4170225       34214138       15.492188         C  18250  545.0
# 506677        4170226       34214147        7.007812         C  15885  545.0
# 506678        4170227       34214153       25.953125         W   7069  111.0
# 506679        4170228       34214214       82.375000         C   2275  555.0
# 506680        4170229       34214216       56.125000         C   5812  408.0
# 506681        4170230       34214253       10.453125         C   5812  408.0
# 506682        4170231       34214261       68.500000         W   7690  122.0
# 506683        4170232       34214269       67.937500         W  12544  321.0
# 506684        4170233       34214271       13.406250         C   3154  408.0
# 506685        4170234       34214277       50.000000         H   9002  453.0
# 506686        4170235       34214279       94.687500         C  13832  375.0
# 506687        4170236       34214287       12.171875         C   3154  408.0
# 506688        4170237       34214326       49.000000         W  16661  490.0
# 506689        4170238       34214337      202.000000         W  16621  516.0
# 506690        4170239       34214345       24.343750         C   5713  168.0
#
#         card3       card4  card5   card6  ...                    id_31  id_32  \
# 0       150.0        visa  226.0   debit  ...                      NaN    NaN
# 1       150.0        visa  226.0   debit  ...                      NaN    NaN
# 2       150.0        visa  226.0   debit  ...                      NaN    NaN
# 3       150.0        visa  166.0   debit  ...                      NaN    NaN
# 4       150.0  mastercard  117.0   debit  ...                      NaN    NaN
# 5       150.0        visa  226.0   debit  ...                      NaN    NaN
# 6       150.0        visa  126.0   debit  ...                      NaN    NaN
# 7       150.0  mastercard  102.0  credit  ...                      NaN    NaN
# 8       150.0        visa  226.0   debit  ...                      NaN    NaN
# 9       150.0        visa  226.0   debit  ...                      NaN    NaN
# 10      150.0  mastercard  224.0   debit  ...                      NaN    NaN
# 11      150.0        visa  226.0   debit  ...                      NaN    NaN
# 12      150.0        visa  226.0   debit  ...                      NaN    NaN
# 13      150.0  mastercard  117.0   debit  ...                      NaN    NaN
# 14      150.0        visa  226.0   debit  ...                      NaN    NaN
# 15      150.0  mastercard  224.0   debit  ...                      NaN    NaN
# 16      150.0  mastercard  224.0   debit  ...                      NaN    NaN
# 17      150.0        visa  226.0   debit  ...                      NaN    NaN
# 18      150.0        visa  126.0   debit  ...                      NaN    NaN
# 19      150.0        visa  226.0   debit  ...                      NaN    NaN
# 20      150.0  mastercard  166.0   debit  ...                      NaN    NaN
# 21      150.0  mastercard  102.0  credit  ...                      NaN    NaN
# 22      150.0  mastercard  117.0   debit  ...                      NaN    NaN
# 23      150.0  mastercard  126.0   debit  ...                      NaN    NaN
# 24      150.0        visa  226.0   debit  ...                      NaN    NaN
# 25      150.0        visa  226.0   debit  ...                      NaN    NaN
# 26      150.0  mastercard  102.0  credit  ...                      NaN    NaN
# 27      150.0        visa  226.0   debit  ...                      NaN    NaN
# 28      150.0  mastercard  126.0   debit  ...                      NaN    NaN
# 29      150.0  mastercard  117.0   debit  ...                      NaN    NaN
# ...       ...         ...    ...     ...  ...                      ...    ...
# 506661  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506662  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506663  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506664  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506665  185.0  mastercard  224.0   debit  ...              chrome 71.0    NaN
# 506666  150.0  mastercard  224.0   debit  ...                      NaN    NaN
# 506667  150.0  mastercard  166.0   debit  ...                      NaN    NaN
# 506668  150.0  mastercard  224.0   debit  ...                      NaN    NaN
# 506669  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506670  185.0  mastercard  224.0   debit  ...              chrome 71.0    NaN
# 506671  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506672  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506673  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506674  185.0        visa  138.0   debit  ...  chrome 71.0 for android    NaN
# 506675  185.0  mastercard  224.0   debit  ...       mobile safari 12.0    NaN
# 506676  185.0        visa  226.0  credit  ...              chrome 71.0    NaN
# 506677  185.0        visa  138.0   debit  ...  chrome 71.0 for android    NaN
# 506678  150.0  mastercard  166.0   debit  ...                      NaN    NaN
# 506679  119.0        visa  137.0  credit  ...  chrome 71.0 for android    NaN
# 506680  185.0  mastercard  224.0   debit  ...              chrome 71.0    NaN
# 506681  185.0  mastercard  224.0   debit  ...  chrome 71.0 for android    NaN
# 506682  150.0  mastercard  166.0   debit  ...                      NaN    NaN
# 506683  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506684  185.0  mastercard  224.0   debit  ...  chrome 71.0 for android    NaN
# 506685  150.0        visa  226.0   debit  ...       mobile safari 10.0   32.0
# 506686  185.0  mastercard  224.0   debit  ...                      NaN    NaN
# 506687  185.0  mastercard  224.0   debit  ...  chrome 43.0 for android    NaN
# 506688  150.0        visa  226.0   debit  ...                      NaN    NaN
# 506689  150.0  mastercard  224.0   debit  ...                      NaN    NaN
# 506690  144.0        visa  147.0  credit  ...      samsung browser 8.2    NaN
#
#            id_33           id_34 id_35 id_36  id_37  id_38  DeviceType  \
# 0            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 1            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 2            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 3            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 4            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 5            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 6            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 7            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 8            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 9            NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 10           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 11           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 12           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 13           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 14           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 15           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 16           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 17           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 18           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 19           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 20           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 21           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 22           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 23           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 24           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 25           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 26           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 27           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 28           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 29           NaN             NaN   NaN   NaN    NaN    NaN         NaN
# ...          ...             ...   ...   ...    ...    ...         ...
# 506661       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506662       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506663       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506664       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506665       NaN             NaN     F     F      T      F     desktop
# 506666       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506667       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506668       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506669       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506670       NaN             NaN     F     F      T      F     desktop
# 506671       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506672       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506673       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506674       NaN             NaN     F     F      T      F      mobile
# 506675       NaN             NaN     F     F      F      F      mobile
# 506676       NaN             NaN     F     F      T      F     desktop
# 506677       NaN             NaN     F     F      T      F      mobile
# 506678       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506679       NaN             NaN     F     F      T      F      mobile
# 506680       NaN             NaN     F     F      T      F     desktop
# 506681       NaN             NaN     F     F      T      F      mobile
# 506682       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506683       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506684       NaN             NaN     F     F      T      F      mobile
# 506685  1334x750  match_status:2     T     F      F      T      mobile
# 506686       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506687       NaN             NaN     F     F      T      F      mobile
# 506688       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506689       NaN             NaN   NaN   NaN    NaN    NaN         NaN
# 506690       NaN             NaN     F     F      T      F      mobile
#
#                          DeviceInfo
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                              NaN
# 28                              NaN
# 29                              NaN
# ...                             ...
# 506661                          NaN
# 506662                          NaN
# 506663                          NaN
# 506664                          NaN
# 506665                      Windows
# 506666                          NaN
# 506667                          NaN
# 506668                          NaN
# 506669                          NaN
# 506670                      Windows
# 506671                          NaN
# 506672                          NaN
# 506673                          NaN
# 506674                      ANE-LX3
# 506675                          NaN
# 506676                      Windows
# 506677                      LG-M250
# 506678                          NaN
# 506679              Moto G (5) Plus
# 506680                          NaN
# 506681                     SM-J700M
# 506682                          NaN
# 506683                          NaN
# 506684                     SM-J320M
# 506685                   iOS Device
# 506686                          NaN
# 506687  ALE-L23 Build/HuaweiALE-L23
# 506688                          NaN
# 506689                          NaN
# 506690                      SAMSUNG
#
# [506691 rows x 433 columns]

# %%
cols_to_drop = [col for col in train.columns if col not in useful_features]
cols_to_drop.remove('isFraud')
# cols_to_drop.remove('TransactionID')
cols_to_drop.remove('TransactionDT')

# %%
'TransactionID' in useful_features
# Out:
# False

# %%
print('{} features are going to be dropped for being useless'.format(len(cols_to_drop)))

train = train.drop(cols_to_drop, axis=1)
test = test.drop(cols_to_drop, axis=1)
# Out:
# 152 features are going to be dropped for being useless

# %%
# New feature - decimal part of the transaction amount
train['TransactionAmt_decimal'] = ((train['TransactionAmt'] - train['TransactionAmt'].astype(int)) * 1000).astype(int)
test['TransactionAmt_decimal'] = ((test['TransactionAmt'] - test['TransactionAmt'].astype(int)) * 1000).astype(int)

# Count encoding for card1 feature. 
# Explained in this kernel: https://www.kaggle.com/nroman/eda-for-cis-fraud-detection
train['card1_count_full'] = train['card1'].map(pd.concat([train['card1'], test['card1']], ignore_index=True).value_counts(dropna=False))
test['card1_count_full'] = test['card1'].map(pd.concat([train['card1'], test['card1']], ignore_index=True).value_counts(dropna=False))

# https://www.kaggle.com/fchmiel/day-and-time-powerful-predictive-feature
train['Transaction_day_of_week'] = np.floor((train['TransactionDT'] / (3600 * 24) - 1) % 7)
test['Transaction_day_of_week'] = np.floor((test['TransactionDT'] / (3600 * 24) - 1) % 7)
train['Transaction_hour'] = np.floor(train['TransactionDT'] / 3600) % 24
test['Transaction_hour'] = np.floor(test['TransactionDT'] / 3600) % 24

# Some arbitrary features interaction
for feature in ['id_02__id_20', 'id_02__D8', 'D11__DeviceInfo', 'DeviceInfo__P_emaildomain', 'P_emaildomain__C2', 
                'card2__dist1', 'card1__card5', 'card2__id_20', 'card5__P_emaildomain', 'addr1__card1']:

    f1, f2 = feature.split('__')
    train[feature] = train[f1].astype(str) + '_' + train[f2].astype(str)
    test[feature] = test[f1].astype(str) + '_' + test[f2].astype(str)

    le = LabelEncoder()
    le.fit(list(train[feature].astype(str).values) + list(test[feature].astype(str).values))
    train[feature] = le.transform(list(train[feature].astype(str).values))
    test[feature] = le.transform(list(test[feature].astype(str).values))
    
for feature in ['id_34', 'id_36']:
    if feature in useful_features:
        # Count encoded for both train and test
        train[feature + '_count_full'] = train[feature].map(pd.concat([train[feature], test[feature]], ignore_index=True).value_counts(dropna=False))
        test[feature + '_count_full'] = test[feature].map(pd.concat([train[feature], test[feature]], ignore_index=True).value_counts(dropna=False))
        
for feature in ['id_01', 'id_31', 'id_33', 'id_35', 'id_36']:
    if feature in useful_features:
        # Count encoded separately for train and test
        train[feature + '_count_dist'] = train[feature].map(train[feature].value_counts(dropna=False))
        test[feature + '_count_dist'] = test[feature].map(test[feature].value_counts(dropna=False))

# %%
for col in tqdm_notebook(train.columns):
    if train[col].dtype == 'object':
        le = LabelEncoder()
        le.fit(list(train[col].astype(str).values) + list(test[col].astype(str).values))
        train[col] = le.transform(list(train[col].astype(str).values))
        test[col] = le.transform(list(test[col].astype(str).values))
# Out:
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))

# %%
X = train.sort_values('TransactionDT').drop(['isFraud', 'TransactionDT', 'TransactionID'], axis=1)
y = train.sort_values('TransactionDT')['isFraud']
test = test.sort_values('TransactionDT').drop(['TransactionDT', 'TransactionID'], axis=1)

# %%
train.reset_index(inplace=True)
test.reset_index(inplace=True)

# %%
del train
gc.collect()
# Out:
# 10839

# %%
X.shape, test.shape
# Out:
# ((590540, 298), (506691, 298))

# %%
params = {'num_leaves': 491,
          'min_child_weight': 0.03454472573214212,
          'feature_fraction': 0.3797454081646243,
          'bagging_fraction': 0.4181193142567742,
          'min_data_in_leaf': 106,
          'objective': 'binary',
          'max_depth': -1,
          'learning_rate': 0.006883242363721497,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3899927210061127,
          'reg_lambda': 0.6485237330340494,
          'random_state': 47
         }

# %%
folds = TimeSeriesSplit(n_splits=5)

aucs = list()
feature_importances = pd.DataFrame()
feature_importances['feature'] = X.columns

training_start_time = time()
for fold, (trn_idx, test_idx) in enumerate(folds.split(X, y)):
    start_time = time()
    print('Training on fold {}'.format(fold + 1))
    
    trn_data = lgb.Dataset(X.iloc[trn_idx], label=y.iloc[trn_idx])
    val_data = lgb.Dataset(X.iloc[test_idx], label=y.iloc[test_idx])
    clf = lgb.train(params, trn_data, 10000, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds=500)
    
    feature_importances['fold_{}'.format(fold + 1)] = clf.feature_importance()
    aucs.append(clf.best_score['valid_1']['auc'])
    
    print('Fold {} finished in {}'.format(fold + 1, str(datetime.timedelta(seconds=time() - start_time))))
print('-' * 30)
print('Training has finished.')
print('Total training time is {}'.format(str(datetime.timedelta(seconds=time() - training_start_time))))
print('Mean AUC:', np.mean(aucs))
print('-' * 30)
# Out:
# Training on fold 1
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.999998	valid_1's auc: 0.90504
# Early stopping, best iteration is:
# [1315]	training's auc: 1	valid_1's auc: 0.905218
# Fold 1 finished in 0:04:37.197513
# Training on fold 2
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.999963	valid_1's auc: 0.92437
# Early stopping, best iteration is:
# [821]	training's auc: 0.999807	valid_1's auc: 0.924938
# Fold 2 finished in 0:05:40.905233
# Training on fold 3
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.999525	valid_1's auc: 0.916118
# Early stopping, best iteration is:
# [1073]	training's auc: 0.9997	valid_1's auc: 0.916438
# Fold 3 finished in 0:07:31.064231
# Training on fold 4
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.998145	valid_1's auc: 0.936278
# Early stopping, best iteration is:
# [1075]	training's auc: 0.998655	valid_1's auc: 0.936437
# Fold 4 finished in 0:09:45.783441
# Training on fold 5
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's auc: 0.996367	valid_1's auc: 0.934028
# Early stopping, best iteration is:
# [1345]	training's auc: 0.998832	valid_1's auc: 0.934758
# Fold 5 finished in 0:13:39.324059
# ------------------------------
# Training has finished.
# Total training time is 0:41:14.297301
# Mean AUC: 0.9235577993342311
# ------------------------------

# %%
feature_importances['average'] = feature_importances[['fold_{}'.format(fold + 1) for fold in range(folds.n_splits)]].mean(axis=1)
feature_importances.to_csv('feature_importances.csv')

plt.figure(figsize=(16, 16))
sns.barplot(data=feature_importances.sort_values(by='average', ascending=False).head(50), x='average', y='feature');
plt.title('50 TOP feature importance over {} folds average'.format(folds.n_splits));

# %%
best_iter = clf.best_iteration

# %%
clf = lgb.LGBMClassifier(**params, num_boost_round=best_iter)
clf.fit(X, y)
# Out:
# LGBMClassifier(bagging_fraction=0.4181193142567742, bagging_seed=11,
#         boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         feature_fraction=0.3797454081646243, importance_type='split',
#         learning_rate=0.006883242363721497, max_depth=-1, metric='auc',
#         min_child_samples=20, min_child_weight=0.03454472573214212,
#         min_data_in_leaf=106, min_split_gain=0.0, n_estimators=100,
#         n_jobs=-1, num_boost_round=1345, num_leaves=491,
#         objective='binary', random_state=47, reg_alpha=0.3899927210061127,
#         reg_lambda=0.6485237330340494, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=0, verbosity=-1)

# %%
sample_submission['isFraud'] = clf.predict_proba(test)[:, 1]

# %%
sample_submission.to_csv('ieee_cis_fraud_detection_v2.csv', index=False)

# %%
sample_submission.reset_index(inplace=True)
